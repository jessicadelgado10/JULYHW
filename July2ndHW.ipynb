# %% [markdown]
# Write a piece of code that plots the historical populations of Cuba, Dominican Republic, Haiti, and Puerto Rico using the data in the file <u>islandsHistPop.csv</u>.  You may add as many code cells as you need.  Make sure to examine the data file.
#
# 1.  Which island has the largest population?
# 2.  When did the population of the Dominican Republic pass that of Haiti?

# %%
# !pip install --user pandas
# Out:
# Requirement already satisfied: pandas in /Users/karinadelgado/opt/anaconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/karinadelgado/opt/anaconda3/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/karinadelgado/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/karinadelgado/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in /Users/karinadelgado/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.read_csv("islandsHistPop.csv")
# Out:
#     Year      Cuba  Dominican Republic    Haiti  Puerto Rico
# 0   1850    907200              136500   543000       380000
# 1   1860   1099400              200000   572000       583300
# 2   1870   1321700              290000   686000       625000
# 3   1880   1409900              300000   880000       754300
# 4   1890   1609100              340000  1085300       839000
# 5   1900   1600000              600000  1294400       986000
# 6   1910   2219000              740000  2029700      1118000
# 7   1920   2997000              879000  1631300      1299800
# 8   1930   3647000             1256000  2380000      1543900
# 9   1940   4291100             1674000  2751000      1869300
# 10  1950   5516000             2353000  3097000      2210700
# 11  1960   7027000             3231000  3623000      2349500
# 12  1970   8569100             4423000  4235000      2712000
# 13  1980   9724000             5697000  5353000      3196500
# 14  1990  10694500             7170000  6486000      3522000
# 15  2000  11142000             8442500  7180300      3808600
# 16  2010  11925000             9335000  8854000      4169000
# 17  2015  12205000             9900000  9434000      4287000

# %%
pop = pd.read_csv("islandsHistPop.csv")
pop
# Out:
#     Year      Cuba  Dominican Republic    Haiti  Puerto Rico
# 0   1850    907200              136500   543000       380000
# 1   1860   1099400              200000   572000       583300
# 2   1870   1321700              290000   686000       625000
# 3   1880   1409900              300000   880000       754300
# 4   1890   1609100              340000  1085300       839000
# 5   1900   1600000              600000  1294400       986000
# 6   1910   2219000              740000  2029700      1118000
# 7   1920   2997000              879000  1631300      1299800
# 8   1930   3647000             1256000  2380000      1543900
# 9   1940   4291100             1674000  2751000      1869300
# 10  1950   5516000             2353000  3097000      2210700
# 11  1960   7027000             3231000  3623000      2349500
# 12  1970   8569100             4423000  4235000      2712000
# 13  1980   9724000             5697000  5353000      3196500
# 14  1990  10694500             7170000  6486000      3522000
# 15  2000  11142000             8442500  7180300      3808600
# 16  2010  11925000             9335000  8854000      4169000
# 17  2015  12205000             9900000  9434000      4287000

# %%
pop.plot( x = "Year", y = "Cuba")
pop.plot( x = "Year", y = "Dominican Republic")
pop.plot( x = "Year", y = "Haiti")
pop.plot( x = "Year", y = "Dominican Republic")

# %%
#1
pop.plot(x= "Year").legend(bbox_to_anchor = (1,1))

# %%
pop["Cuba"]
# Out:
# 0       907200
# 1      1099400
# 2      1321700
# 3      1409900
# 4      1609100
# 5      1600000
# 6      2219000
# 7      2997000
# 8      3647000
# 9      4291100
# 10     5516000
# 11     7027000
# 12     8569100
# 13     9724000
# 14    10694500
# 15    11142000
# 16    11925000
# 17    12205000
# Name: Cuba, dtype: int64

# %%
#2
pop.plot(x= "Year").legend(bbox_to_anchor = (1,1))

# %%
# around 1970
